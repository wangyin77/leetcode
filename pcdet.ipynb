# %%
# !nvcc --version
# !wget -c https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# !chmod +x Anaconda3-5.1.0-Linux-x86_64.sh
# !bash ./Anaconda3-5.1.0-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# --2020-12-17 07:40:00--  https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-5.1.0-Linux-x86_64.sh [following]
# --2020-12-17 07:40:01--  https://repo.anaconda.com/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 577996269 (551M) [application/x-sh]
# ...

# %%
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages')

# %%
# !which conda
# !conda create -n pcdet python=3.7.7 pytorch==1.3.1 torchvision cudatoolkit==10.1.243 cmake mayavi -c pytorch --yes
# Out:
# /usr/local/bin/conda
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/pcdet
#
#   added / updated specs:
#     - cmake
#     - cudatoolkit==10.1.243
#     - mayavi
#     - python=3.7.7
#     - pytorch==1.3.1
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h7b6447c_0         105 KB
#     mkl_random-1.1.1           |   py37h0573a6f_0         375 KB
#     pyqt-5.9.2                 |   py37h05f1152_2         5.6 MB
#     freetype-2.10.4            |       h5ab3b9f_0         901 KB
#     numpy-1.19.2               |   py37h54aff64_0          21 KB
#     tbb-2020.3                 |       hfd86e86_0         1.4 MB
# ...

# %%
# %%bash
# source activate pcdet
# python
# import torch
# print(torch.__version__)
# print(torch.cuda.is_available())

# %%
# !git clone https://github.com/traveller59/spconv.git --recursive

# %%
# !apt-get install aptitude
# !aptitude install libboost-all-dev

# %%
# %%bash
# source activate pcdet
# conda list
# apt-get install aptitude
# aptitude install libboost-all-dev
# conda list

# %%
# %%bash
# source activate pcdet
# cd spconv
# python setup.py bdist_wheel

# %%
# %%bash
# source activate pcdet
# pip install /content/spconv/dist/spconv-1.2.1-cp37-cp37m-linux_x86_64.whl

# %%
# !git clone https://github.com/open-mmlab/OpenPCDet.git

# %%
# %%bash
# source activate pcdet
# pip install -r /content/OpenPCDet/requirements.txt
# cd OpenPCDet
# python setup.py develop

# %%
# %%bash
# source activate pcdet
# cd OpenPCDet
# python demo.py --cfg_file cfgs/kitti_models/pv_rcnn.yaml \
#     --ckpt pv_rcnn_8369.pth \
#     --data_path data/kitti/training/velodyne/000008.bin
